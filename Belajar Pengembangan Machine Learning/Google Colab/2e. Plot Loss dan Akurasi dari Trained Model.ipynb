# %% [markdown]
# Di modul sebelumnya kita pasti penasaran kenapa menampung fungsi `fit` pada sebuah objek history. Jawabannya adalah karena kita dapat membuat *plot* dari **akurasi** dan **loss model** kita pada saat proses pelatihan.
#
# *Plot* ini sangat berguna untuk melihat proses keseluruhan pembelajaran model seiring waktu. Untuk melihat bagaimana *plot* bekerja kita kerjakan latihan berikut. Kita akan menggunakan dataset dan model yang sama dengan latihan sebelumnya.

# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense

# %%
df = pd.read_csv('/content/sample_data/Iris.csv')
df
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df = df.drop(columns='Id')

# %%
category = pd.get_dummies(df.Species)
category
# Out:
#      Iris-setosa  Iris-versicolor  Iris-virginica
# 0              1                0               0
# 1              1                0               0
# 2              1                0               0
# 3              1                0               0
# 4              1                0               0
# ..           ...              ...             ...
# 145            0                0               1
# 146            0                0               1
# 147            0                0               1
# 148            0                0               1
# 149            0                0               1
#
# [150 rows x 3 columns]

# %%
new_df = pd.concat([df, category], axis=1)
new_df = new_df.drop(columns='Species')
new_df
# Out:
#      SepalLengthCm  SepalWidthCm  ...  Iris-versicolor  Iris-virginica
# 0              5.1           3.5  ...                0               0
# 1              4.9           3.0  ...                0               0
# 2              4.7           3.2  ...                0               0
# 3              4.6           3.1  ...                0               0
# 4              5.0           3.6  ...                0               0
# ..             ...           ...  ...              ...             ...
# 145            6.7           3.0  ...                0               1
# 146            6.3           2.5  ...                0               1
# 147            6.5           3.0  ...                0               1
# 148            6.2           3.4  ...                0               1
# 149            5.9           3.0  ...                0               1
#
# [150 rows x 7 columns]

# %%
dataset = new_df.values
dataset
# Out:
# array([[5.1, 3.5, 1.4, ..., 1. , 0. , 0. ],
#        [4.9, 3. , 1.4, ..., 1. , 0. , 0. ],
#        [4.7, 3.2, 1.3, ..., 1. , 0. , 0. ],
#        ...,
#        [6.5, 3. , 5.2, ..., 0. , 0. , 1. ],
#        [6.2, 3.4, 5.4, ..., 0. , 0. , 1. ],
#        [5.9, 3. , 5.1, ..., 0. , 0. , 1. ]])

# %%
# Pilih 4 kolom pertama untuk dijadikan sebagai atribut
X = dataset[:,0:4]
# Pilih 3 kolom terakhir sebagai label
y = dataset[:,4:7]

# %%
# Normalize
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)
X_scale
# Out:
# array([[0.22222222, 0.625     , 0.06779661, 0.04166667],
#        [0.16666667, 0.41666667, 0.06779661, 0.04166667],
#        [0.11111111, 0.5       , 0.05084746, 0.04166667],
#        [0.08333333, 0.45833333, 0.08474576, 0.04166667],
#        [0.19444444, 0.66666667, 0.06779661, 0.04166667],
#        [0.30555556, 0.79166667, 0.11864407, 0.125     ],
#        [0.08333333, 0.58333333, 0.06779661, 0.08333333],
#        [0.19444444, 0.58333333, 0.08474576, 0.04166667],
#        [0.02777778, 0.375     , 0.06779661, 0.04166667],
#        [0.16666667, 0.45833333, 0.08474576, 0.        ],
#        [0.30555556, 0.70833333, 0.08474576, 0.04166667],
#        [0.13888889, 0.58333333, 0.10169492, 0.04166667],
#        [0.13888889, 0.41666667, 0.06779661, 0.        ],
#        [0.        , 0.41666667, 0.01694915, 0.        ],
#        [0.41666667, 0.83333333, 0.03389831, 0.04166667],
#        [0.38888889, 1.        , 0.08474576, 0.125     ],
#        [0.30555556, 0.79166667, 0.05084746, 0.125     ],
#        [0.22222222, 0.625     , 0.06779661, 0.08333333],
#        [0.38888889, 0.75      , 0.11864407, 0.08333333],
#        [0.22222222, 0.75      , 0.08474576, 0.08333333],
#        [0.30555556, 0.58333333, 0.11864407, 0.04166667],
#        [0.22222222, 0.70833333, 0.08474576, 0.125     ],
#        [0.08333333, 0.66666667, 0.        , 0.04166667],
#        [0.22222222, 0.54166667, 0.11864407, 0.16666667],
#        [0.13888889, 0.58333333, 0.15254237, 0.04166667],
#        [0.19444444, 0.41666667, 0.10169492, 0.04166667],
#        [0.19444444, 0.58333333, 0.10169492, 0.125     ],
#        [0.25      , 0.625     , 0.08474576, 0.04166667],
#        [0.25      , 0.58333333, 0.06779661, 0.04166667],
#        [0.11111111, 0.5       , 0.10169492, 0.04166667],
#        [0.13888889, 0.45833333, 0.10169492, 0.04166667],
#        [0.30555556, 0.58333333, 0.08474576, 0.125     ],
#        [0.25      , 0.875     , 0.08474576, 0.        ],
#        [0.33333333, 0.91666667, 0.06779661, 0.04166667],
#        [0.16666667, 0.45833333, 0.08474576, 0.        ],
#        [0.19444444, 0.5       , 0.03389831, 0.04166667],
#        [0.33333333, 0.625     , 0.05084746, 0.04166667],
#        [0.16666667, 0.45833333, 0.08474576, 0.        ],
#        [0.02777778, 0.41666667, 0.05084746, 0.04166667],
#        [0.22222222, 0.58333333, 0.08474576, 0.04166667],
#        [0.19444444, 0.625     , 0.05084746, 0.08333333],
#        [0.05555556, 0.125     , 0.05084746, 0.08333333],
#        [0.02777778, 0.5       , 0.05084746, 0.04166667],
#        [0.19444444, 0.625     , 0.10169492, 0.20833333],
#        [0.22222222, 0.75      , 0.15254237, 0.125     ],
#        [0.13888889, 0.41666667, 0.06779661, 0.08333333],
#        [0.22222222, 0.75      , 0.10169492, 0.04166667],
#        [0.08333333, 0.5       , 0.06779661, 0.04166667],
#        [0.27777778, 0.70833333, 0.08474576, 0.04166667],
#        [0.19444444, 0.54166667, 0.06779661, 0.04166667],
#        [0.75      , 0.5       , 0.62711864, 0.54166667],
#        [0.58333333, 0.5       , 0.59322034, 0.58333333],
#        [0.72222222, 0.45833333, 0.66101695, 0.58333333],
#        [0.33333333, 0.125     , 0.50847458, 0.5       ],
#        [0.61111111, 0.33333333, 0.61016949, 0.58333333],
#        [0.38888889, 0.33333333, 0.59322034, 0.5       ],
#        [0.55555556, 0.54166667, 0.62711864, 0.625     ],
#        [0.16666667, 0.16666667, 0.38983051, 0.375     ],
#        [0.63888889, 0.375     , 0.61016949, 0.5       ],
#        [0.25      , 0.29166667, 0.49152542, 0.54166667],
#        [0.19444444, 0.        , 0.42372881, 0.375     ],
#        [0.44444444, 0.41666667, 0.54237288, 0.58333333],
#        [0.47222222, 0.08333333, 0.50847458, 0.375     ],
#        [0.5       , 0.375     , 0.62711864, 0.54166667],
#        [0.36111111, 0.375     , 0.44067797, 0.5       ],
#        [0.66666667, 0.45833333, 0.57627119, 0.54166667],
#        [0.36111111, 0.41666667, 0.59322034, 0.58333333],
#        [0.41666667, 0.29166667, 0.52542373, 0.375     ],
#        [0.52777778, 0.08333333, 0.59322034, 0.58333333],
#        [0.36111111, 0.20833333, 0.49152542, 0.41666667],
#        [0.44444444, 0.5       , 0.6440678 , 0.70833333],
#        [0.5       , 0.33333333, 0.50847458, 0.5       ],
#        [0.55555556, 0.20833333, 0.66101695, 0.58333333],
#        [0.5       , 0.33333333, 0.62711864, 0.45833333],
#        [0.58333333, 0.375     , 0.55932203, 0.5       ],
#        [0.63888889, 0.41666667, 0.57627119, 0.54166667],
#        [0.69444444, 0.33333333, 0.6440678 , 0.54166667],
#        [0.66666667, 0.41666667, 0.6779661 , 0.66666667],
#        [0.47222222, 0.375     , 0.59322034, 0.58333333],
#        [0.38888889, 0.25      , 0.42372881, 0.375     ],
#        [0.33333333, 0.16666667, 0.47457627, 0.41666667],
#        [0.33333333, 0.16666667, 0.45762712, 0.375     ],
#        [0.41666667, 0.29166667, 0.49152542, 0.45833333],
#        [0.47222222, 0.29166667, 0.69491525, 0.625     ],
#        [0.30555556, 0.41666667, 0.59322034, 0.58333333],
#        [0.47222222, 0.58333333, 0.59322034, 0.625     ],
#        [0.66666667, 0.45833333, 0.62711864, 0.58333333],
#        [0.55555556, 0.125     , 0.57627119, 0.5       ],
#        [0.36111111, 0.41666667, 0.52542373, 0.5       ],
#        [0.33333333, 0.20833333, 0.50847458, 0.5       ],
#        [0.33333333, 0.25      , 0.57627119, 0.45833333],
#        [0.5       , 0.41666667, 0.61016949, 0.54166667],
#        [0.41666667, 0.25      , 0.50847458, 0.45833333],
#        [0.19444444, 0.125     , 0.38983051, 0.375     ],
#        [0.36111111, 0.29166667, 0.54237288, 0.5       ],
#        [0.38888889, 0.41666667, 0.54237288, 0.45833333],
#        [0.38888889, 0.375     , 0.54237288, 0.5       ],
#        [0.52777778, 0.375     , 0.55932203, 0.5       ],
#        [0.22222222, 0.20833333, 0.33898305, 0.41666667],
#        [0.38888889, 0.33333333, 0.52542373, 0.5       ],
#        [0.55555556, 0.54166667, 0.84745763, 1.        ],
#        [0.41666667, 0.29166667, 0.69491525, 0.75      ],
#        [0.77777778, 0.41666667, 0.83050847, 0.83333333],
#        [0.55555556, 0.375     , 0.77966102, 0.70833333],
#        [0.61111111, 0.41666667, 0.81355932, 0.875     ],
#        [0.91666667, 0.41666667, 0.94915254, 0.83333333],
#        [0.16666667, 0.20833333, 0.59322034, 0.66666667],
#        [0.83333333, 0.375     , 0.89830508, 0.70833333],
#        [0.66666667, 0.20833333, 0.81355932, 0.70833333],
#        [0.80555556, 0.66666667, 0.86440678, 1.        ],
#        [0.61111111, 0.5       , 0.69491525, 0.79166667],
#        [0.58333333, 0.29166667, 0.72881356, 0.75      ],
#        [0.69444444, 0.41666667, 0.76271186, 0.83333333],
#        [0.38888889, 0.20833333, 0.6779661 , 0.79166667],
#        [0.41666667, 0.33333333, 0.69491525, 0.95833333],
#        [0.58333333, 0.5       , 0.72881356, 0.91666667],
#        [0.61111111, 0.41666667, 0.76271186, 0.70833333],
#        [0.94444444, 0.75      , 0.96610169, 0.875     ],
#        [0.94444444, 0.25      , 1.        , 0.91666667],
#        [0.47222222, 0.08333333, 0.6779661 , 0.58333333],
#        [0.72222222, 0.5       , 0.79661017, 0.91666667],
#        [0.36111111, 0.33333333, 0.66101695, 0.79166667],
#        [0.94444444, 0.33333333, 0.96610169, 0.79166667],
#        [0.55555556, 0.29166667, 0.66101695, 0.70833333],
#        [0.66666667, 0.54166667, 0.79661017, 0.83333333],
#        [0.80555556, 0.5       , 0.84745763, 0.70833333],
#        [0.52777778, 0.33333333, 0.6440678 , 0.70833333],
#        [0.5       , 0.41666667, 0.66101695, 0.70833333],
#        [0.58333333, 0.33333333, 0.77966102, 0.83333333],
#        [0.80555556, 0.41666667, 0.81355932, 0.625     ],
#        [0.86111111, 0.33333333, 0.86440678, 0.75      ],
#        [1.        , 0.75      , 0.91525424, 0.79166667],
#        [0.58333333, 0.33333333, 0.77966102, 0.875     ],
#        [0.55555556, 0.33333333, 0.69491525, 0.58333333],
#        [0.5       , 0.25      , 0.77966102, 0.54166667],
#        [0.94444444, 0.41666667, 0.86440678, 0.91666667],
#        [0.55555556, 0.58333333, 0.77966102, 0.95833333],
#        [0.58333333, 0.45833333, 0.76271186, 0.70833333],
#        [0.47222222, 0.41666667, 0.6440678 , 0.70833333],
#        [0.72222222, 0.45833333, 0.74576271, 0.83333333],
#        [0.66666667, 0.45833333, 0.77966102, 0.95833333],
#        [0.72222222, 0.45833333, 0.69491525, 0.91666667],
#        [0.41666667, 0.29166667, 0.69491525, 0.75      ],
#        [0.69444444, 0.5       , 0.83050847, 0.91666667],
#        [0.66666667, 0.54166667, 0.79661017, 1.        ],
#        [0.66666667, 0.41666667, 0.71186441, 0.91666667],
#        [0.55555556, 0.20833333, 0.6779661 , 0.75      ],
#        [0.61111111, 0.41666667, 0.71186441, 0.79166667],
#        [0.52777778, 0.58333333, 0.74576271, 0.91666667],
#        [0.44444444, 0.41666667, 0.69491525, 0.70833333]])

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, y, test_size=0.3)

# %%
model = Sequential([
                    Dense(64, activation='relu', input_shape=(4,)),
                    Dense(64, activation='relu'),
                    Dense(3, activation='softmax')
])

# %%
model.compile(optimizer='Adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Hasilnya sebagai berikut:
hist = model.fit(X_train, Y_train, epochs=100)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 4ms/step - loss: 1.0866 - accuracy: 0.6190
# Epoch 2/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0426 - accuracy: 0.6762
# Epoch 3/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0016 - accuracy: 0.6762
# Epoch 4/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9615 - accuracy: 0.6762
# Epoch 5/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9233 - accuracy: 0.6762
# Epoch 6/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8845 - accuracy: 0.6762
# Epoch 7/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8472 - accuracy: 0.6762
# Epoch 8/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8071 - accuracy: 0.6762
# Epoch 9/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7681 - accuracy: 0.6762
# Epoch 10/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7295 - accuracy: 0.6762
# Epoch 11/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6926 - accuracy: 0.6762
# Epoch 12/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6585 - accuracy: 0.6762
# Epoch 13/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6238 - accuracy: 0.6762
# Epoch 14/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5922 - accuracy: 0.6762
# Epoch 15/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5647 - accuracy: 0.6762
# Epoch 16/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5373 - accuracy: 0.7333
# Epoch 17/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5144 - accuracy: 0.8190
# Epoch 18/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4948 - accuracy: 0.9048
# Epoch 19/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4755 - accuracy: 0.9048
# Epoch 20/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4589 - accuracy: 0.8667
# Epoch 21/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4438 - accuracy: 0.8381
# Epoch 22/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4307 - accuracy: 0.8952
# Epoch 23/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4195 - accuracy: 0.9429
# Epoch 24/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4080 - accuracy: 0.9524
# Epoch 25/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3966 - accuracy: 0.9619
# Epoch 26/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3867 - accuracy: 0.9429
# Epoch 27/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3777 - accuracy: 0.9333
# Epoch 28/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3673 - accuracy: 0.9333
# Epoch 29/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3569 - accuracy: 0.9524
# Epoch 30/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3478 - accuracy: 0.9619
# Epoch 31/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3383 - accuracy: 0.9619
# Epoch 32/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3290 - accuracy: 0.9619
# Epoch 33/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3195 - accuracy: 0.9619
# Epoch 34/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3135 - accuracy: 0.9714
# Epoch 35/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3068 - accuracy: 0.9714
# Epoch 36/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2956 - accuracy: 0.9714
# Epoch 37/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2856 - accuracy: 0.9714
# Epoch 38/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2768 - accuracy: 0.9714
# Epoch 39/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2668 - accuracy: 0.9619
# Epoch 40/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2592 - accuracy: 0.9714
# Epoch 41/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2541 - accuracy: 0.9619
# Epoch 42/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2447 - accuracy: 0.9714
# Epoch 43/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2342 - accuracy: 0.9714
# Epoch 44/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2261 - accuracy: 0.9714
# Epoch 45/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2206 - accuracy: 0.9714
# Epoch 46/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2108 - accuracy: 0.9714
# Epoch 47/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2032 - accuracy: 0.9714
# Epoch 48/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1962 - accuracy: 0.9714
# Epoch 49/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1881 - accuracy: 0.9810
# Epoch 50/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1821 - accuracy: 0.9714
# Epoch 51/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1782 - accuracy: 0.9810
# Epoch 52/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1703 - accuracy: 0.9714
# Epoch 53/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1641 - accuracy: 0.9810
# Epoch 54/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1603 - accuracy: 0.9714
# Epoch 55/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1545 - accuracy: 0.9905
# Epoch 56/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1490 - accuracy: 0.9714
# Epoch 57/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1436 - accuracy: 0.9810
# Epoch 58/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1421 - accuracy: 0.9714
# Epoch 59/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1366 - accuracy: 0.9810
# Epoch 60/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1298 - accuracy: 0.9905
# Epoch 61/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1261 - accuracy: 0.9905
# Epoch 62/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1226 - accuracy: 0.9905
# Epoch 63/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1193 - accuracy: 0.9905
# Epoch 64/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1161 - accuracy: 0.9905
# Epoch 65/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1121 - accuracy: 0.9905
# Epoch 66/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1091 - accuracy: 0.9905
# Epoch 67/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1068 - accuracy: 0.9905
# Epoch 68/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1038 - accuracy: 0.9905
# Epoch 69/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1010 - accuracy: 0.9905
# Epoch 70/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1016 - accuracy: 0.9810
# Epoch 71/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0982 - accuracy: 0.9810
# Epoch 72/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0941 - accuracy: 0.9905
# Epoch 73/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0928 - accuracy: 0.9905
# Epoch 74/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0928 - accuracy: 0.9810
# Epoch 75/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0852 - accuracy: 0.9905
# Epoch 76/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0908 - accuracy: 0.9810
# Epoch 77/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0889 - accuracy: 0.9905
# Epoch 78/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0820 - accuracy: 0.9905
# Epoch 79/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0803 - accuracy: 0.9905
# Epoch 80/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0785 - accuracy: 0.9905
# Epoch 81/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0771 - accuracy: 0.9905
# Epoch 82/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0754 - accuracy: 0.9905
# Epoch 83/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0742 - accuracy: 0.9905
# Epoch 84/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0732 - accuracy: 0.9905
# Epoch 85/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0710 - accuracy: 0.9905
# Epoch 86/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0717 - accuracy: 0.9905
# Epoch 87/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0682 - accuracy: 0.9905
# Epoch 88/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0764 - accuracy: 0.9810
# Epoch 89/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0685 - accuracy: 0.9905
# Epoch 90/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0691 - accuracy: 0.9905
# Epoch 91/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0706 - accuracy: 0.9810
# Epoch 92/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0651 - accuracy: 0.9905
# Epoch 93/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0636 - accuracy: 0.9810
# Epoch 94/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0638 - accuracy: 0.9810
# Epoch 95/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0634 - accuracy: 0.9810
# Epoch 96/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0615 - accuracy: 0.9905
# Epoch 97/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0605 - accuracy: 0.9905
# Epoch 98/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0594 - accuracy: 0.9905
# Epoch 99/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0582 - accuracy: 0.9905
# Epoch 100/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0576 - accuracy: 0.9905

# %%
model.evaluate(X_test, Y_test)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2314 - accuracy: 0.9111
# [0.23140475153923035, 0.9111111164093018]

# %% [markdown]
# ---
#
#
# Anda dapat menggunakan latihan sebelumnya dan menambahkan kode-kode berikut di bawah latihan sebelumnya.

# %% [markdown]
# Impor library matplotlib terlebih dahulu.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Kemudian dengan objek `pyplot` kita akan melakukan **plot** dari objek `history`. Objek `history` menampung informasi dari akurasi dan loss model pada setiap epoch di proses pelatihan. Sehingga kita bisa membuat plot akurasi atau loss dari model. Kode di bawah menunjukkan bagaimana kita bisa membuat plot loss dari model. Untuk mengakses loss kita bisa memanggil fungsi `history` pada objek `history` dan memilih metrik loss. Dari hasil plot loss di bawah Anda dapat hat bahwa loss model berkurang sangat signifikan dari epoch pertama sampai ke epoch ke-100.

# %%
plt.plot(hist.history['loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper right')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# Untuk membuat plot dari akurasi kita bisa memilih metrik accuracy pada fungsi `history`. Dari hasil plot di bawah, cek bahwa akurasi model stagnan pada epoch di sekitar 20 dan juga kembali stagnan pada epoch di atas 80.

# %%
plt.plot(hist.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='lower right')
plt.show()

# %% [markdown]
# # Selamat, Anda telah memahami bagaimana membuat plot akurasi dan loss dari model Anda. Pada modul-modul selanjutnya kita akan membahas lebih dalam bagaimana menggunakan plot ini untuk mendeteksi overfitting dan underfitting.
