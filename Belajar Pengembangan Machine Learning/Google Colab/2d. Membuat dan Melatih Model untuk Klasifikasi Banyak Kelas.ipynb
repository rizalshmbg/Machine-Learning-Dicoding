# %% [markdown]
# Pada submodul kali ini kita akan melanjutkan dengan pengembangan model jst untuk klasifikasi multi-kelas. Aplikasi dari klasifikasi multi kelas sangat banyak, lebih banyak dari klasifikasi biner. Contohnya seperti produk-produk pada toko online dan program pengenalan wajah. Tentu terdapat lebih dari 2 jenis wajah manusia di bumi ini bukan?
#
# Nah langsung saja kita mulai latihan kita. Pada kelas sebelumnya kita telah belajar mengklasifikasi dataset iris menggunakan decision tree. Di submodul ini kita akan belajar menggunakan jst untuk mengklasifikasikan spesies bunga iris. Silahkan unduh data di [tautan berikut](https://www.kaggle.com/uciml/iris) dan jangan lupa masukkan ke dalam Colaboratory.
#
# Pertama impor library yang dibutuhkan untuk latihan kita.

# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# Kemudian kita gunakan fungsi `read_csv()` untuk mengubah dataset menjadi pandas dataframe. Untuk menampilkan dataframe kita hanya perlu menulis nama dari dataframe kita.

# %%
df = pd.read_csv('/content/sample_data/Iris.csv')
df
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# Dapat kita lihat bahwa terdapat kolom id yang tidak ada hubungan dengan label sehingga kita perlu membuang kolom tersebut. Untuk membuang kolom dari dataframe gunakan fungsi `drop()`.

# %%
df = df.drop(columns='Id')

# %% [markdown]
# Selanjutnya kita perlu melakukan **one hot encoding** karena label kita merupakan data kategorikal. Fungsi `get_dummies()` memudahkan kita untuk melakukan hal ini.

# %%
category = pd.get_dummies(df.Species)
category
# Out:
#      Iris-setosa  Iris-versicolor  Iris-virginica
# 0              1                0               0
# 1              1                0               0
# 2              1                0               0
# 3              1                0               0
# 4              1                0               0
# ..           ...              ...             ...
# 145            0                0               1
# 146            0                0               1
# 147            0                0               1
# 148            0                0               1
# 149            0                0               1
#
# [150 rows x 3 columns]

# %% [markdown]
# Kemudian, kita perlu menggabungkan kolom hasil **one hot encoding** dan membuang kolom spesies karena kolom tersebut tidak akan dipakai.

# %%
new_df = pd.concat([df, category], axis=1)
new_df = new_df.drop(columns='Species')
new_df
# Out:
#      SepalLengthCm  SepalWidthCm  ...  Iris-versicolor  Iris-virginica
# 0              5.1           3.5  ...                0               0
# 1              4.9           3.0  ...                0               0
# 2              4.7           3.2  ...                0               0
# 3              4.6           3.1  ...                0               0
# 4              5.0           3.6  ...                0               0
# ..             ...           ...  ...              ...             ...
# 145            6.7           3.0  ...                0               1
# 146            6.3           2.5  ...                0               1
# 147            6.5           3.0  ...                0               1
# 148            6.2           3.4  ...                0               1
# 149            5.9           3.0  ...                0               1
#
# [150 rows x 7 columns]

# %% [markdown]
# Selanjutnya setelah dataframe kita olah, kita konversi dataframe tersebut menjadi numpy array dengan fungsi `values` dari dataframe.

# %%
dataset = new_df.values
dataset
# Out:
# array([[5.1, 3.5, 1.4, ..., 1. , 0. , 0. ],
#        [4.9, 3. , 1.4, ..., 1. , 0. , 0. ],
#        [4.7, 3.2, 1.3, ..., 1. , 0. , 0. ],
#        ...,
#        [6.5, 3. , 5.2, ..., 0. , 0. , 1. ],
#        [6.2, 3.4, 5.4, ..., 0. , 0. , 1. ],
#        [5.9, 3. , 5.1, ..., 0. , 0. , 1. ]])

# %% [markdown]
# Nah, tahap berikutnya adalah kita memisahkan antara atribut dan label dengan menjalankan kode di bawah.

# %%
# Pilih 4 kolom pertama untuk dijadikan sebagai atribut
X = dataset[:,0:4]
# Pilih 3 kolom terakhir sebagai label
y = dataset[:,4:7]

# %% [markdown]
# Lalu, kite perlu lakukan normalisasi data agar data dapat dipelajari dengan baik oleh jst kita.

# %%
# Normalize
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)
X_scale
# Out:
# array([[0.22222222, 0.625     , 0.06779661, 0.04166667],
#        [0.16666667, 0.41666667, 0.06779661, 0.04166667],
#        [0.11111111, 0.5       , 0.05084746, 0.04166667],
#        [0.08333333, 0.45833333, 0.08474576, 0.04166667],
#        [0.19444444, 0.66666667, 0.06779661, 0.04166667],
#        [0.30555556, 0.79166667, 0.11864407, 0.125     ],
#        [0.08333333, 0.58333333, 0.06779661, 0.08333333],
#        [0.19444444, 0.58333333, 0.08474576, 0.04166667],
#        [0.02777778, 0.375     , 0.06779661, 0.04166667],
#        [0.16666667, 0.45833333, 0.08474576, 0.        ],
#        [0.30555556, 0.70833333, 0.08474576, 0.04166667],
#        [0.13888889, 0.58333333, 0.10169492, 0.04166667],
#        [0.13888889, 0.41666667, 0.06779661, 0.        ],
#        [0.        , 0.41666667, 0.01694915, 0.        ],
#        [0.41666667, 0.83333333, 0.03389831, 0.04166667],
#        [0.38888889, 1.        , 0.08474576, 0.125     ],
#        [0.30555556, 0.79166667, 0.05084746, 0.125     ],
#        [0.22222222, 0.625     , 0.06779661, 0.08333333],
#        [0.38888889, 0.75      , 0.11864407, 0.08333333],
#        [0.22222222, 0.75      , 0.08474576, 0.08333333],
#        [0.30555556, 0.58333333, 0.11864407, 0.04166667],
#        [0.22222222, 0.70833333, 0.08474576, 0.125     ],
#        [0.08333333, 0.66666667, 0.        , 0.04166667],
#        [0.22222222, 0.54166667, 0.11864407, 0.16666667],
#        [0.13888889, 0.58333333, 0.15254237, 0.04166667],
#        [0.19444444, 0.41666667, 0.10169492, 0.04166667],
#        [0.19444444, 0.58333333, 0.10169492, 0.125     ],
#        [0.25      , 0.625     , 0.08474576, 0.04166667],
#        [0.25      , 0.58333333, 0.06779661, 0.04166667],
#        [0.11111111, 0.5       , 0.10169492, 0.04166667],
#        [0.13888889, 0.45833333, 0.10169492, 0.04166667],
#        [0.30555556, 0.58333333, 0.08474576, 0.125     ],
#        [0.25      , 0.875     , 0.08474576, 0.        ],
#        [0.33333333, 0.91666667, 0.06779661, 0.04166667],
#        [0.16666667, 0.45833333, 0.08474576, 0.        ],
#        [0.19444444, 0.5       , 0.03389831, 0.04166667],
#        [0.33333333, 0.625     , 0.05084746, 0.04166667],
#        [0.16666667, 0.45833333, 0.08474576, 0.        ],
#        [0.02777778, 0.41666667, 0.05084746, 0.04166667],
#        [0.22222222, 0.58333333, 0.08474576, 0.04166667],
#        [0.19444444, 0.625     , 0.05084746, 0.08333333],
#        [0.05555556, 0.125     , 0.05084746, 0.08333333],
#        [0.02777778, 0.5       , 0.05084746, 0.04166667],
#        [0.19444444, 0.625     , 0.10169492, 0.20833333],
#        [0.22222222, 0.75      , 0.15254237, 0.125     ],
#        [0.13888889, 0.41666667, 0.06779661, 0.08333333],
#        [0.22222222, 0.75      , 0.10169492, 0.04166667],
#        [0.08333333, 0.5       , 0.06779661, 0.04166667],
#        [0.27777778, 0.70833333, 0.08474576, 0.04166667],
#        [0.19444444, 0.54166667, 0.06779661, 0.04166667],
#        [0.75      , 0.5       , 0.62711864, 0.54166667],
#        [0.58333333, 0.5       , 0.59322034, 0.58333333],
#        [0.72222222, 0.45833333, 0.66101695, 0.58333333],
#        [0.33333333, 0.125     , 0.50847458, 0.5       ],
#        [0.61111111, 0.33333333, 0.61016949, 0.58333333],
#        [0.38888889, 0.33333333, 0.59322034, 0.5       ],
#        [0.55555556, 0.54166667, 0.62711864, 0.625     ],
#        [0.16666667, 0.16666667, 0.38983051, 0.375     ],
#        [0.63888889, 0.375     , 0.61016949, 0.5       ],
#        [0.25      , 0.29166667, 0.49152542, 0.54166667],
#        [0.19444444, 0.        , 0.42372881, 0.375     ],
#        [0.44444444, 0.41666667, 0.54237288, 0.58333333],
#        [0.47222222, 0.08333333, 0.50847458, 0.375     ],
#        [0.5       , 0.375     , 0.62711864, 0.54166667],
#        [0.36111111, 0.375     , 0.44067797, 0.5       ],
#        [0.66666667, 0.45833333, 0.57627119, 0.54166667],
#        [0.36111111, 0.41666667, 0.59322034, 0.58333333],
#        [0.41666667, 0.29166667, 0.52542373, 0.375     ],
#        [0.52777778, 0.08333333, 0.59322034, 0.58333333],
#        [0.36111111, 0.20833333, 0.49152542, 0.41666667],
#        [0.44444444, 0.5       , 0.6440678 , 0.70833333],
#        [0.5       , 0.33333333, 0.50847458, 0.5       ],
#        [0.55555556, 0.20833333, 0.66101695, 0.58333333],
#        [0.5       , 0.33333333, 0.62711864, 0.45833333],
#        [0.58333333, 0.375     , 0.55932203, 0.5       ],
#        [0.63888889, 0.41666667, 0.57627119, 0.54166667],
#        [0.69444444, 0.33333333, 0.6440678 , 0.54166667],
#        [0.66666667, 0.41666667, 0.6779661 , 0.66666667],
#        [0.47222222, 0.375     , 0.59322034, 0.58333333],
#        [0.38888889, 0.25      , 0.42372881, 0.375     ],
#        [0.33333333, 0.16666667, 0.47457627, 0.41666667],
#        [0.33333333, 0.16666667, 0.45762712, 0.375     ],
#        [0.41666667, 0.29166667, 0.49152542, 0.45833333],
#        [0.47222222, 0.29166667, 0.69491525, 0.625     ],
#        [0.30555556, 0.41666667, 0.59322034, 0.58333333],
#        [0.47222222, 0.58333333, 0.59322034, 0.625     ],
#        [0.66666667, 0.45833333, 0.62711864, 0.58333333],
#        [0.55555556, 0.125     , 0.57627119, 0.5       ],
#        [0.36111111, 0.41666667, 0.52542373, 0.5       ],
#        [0.33333333, 0.20833333, 0.50847458, 0.5       ],
#        [0.33333333, 0.25      , 0.57627119, 0.45833333],
#        [0.5       , 0.41666667, 0.61016949, 0.54166667],
#        [0.41666667, 0.25      , 0.50847458, 0.45833333],
#        [0.19444444, 0.125     , 0.38983051, 0.375     ],
#        [0.36111111, 0.29166667, 0.54237288, 0.5       ],
#        [0.38888889, 0.41666667, 0.54237288, 0.45833333],
#        [0.38888889, 0.375     , 0.54237288, 0.5       ],
#        [0.52777778, 0.375     , 0.55932203, 0.5       ],
#        [0.22222222, 0.20833333, 0.33898305, 0.41666667],
#        [0.38888889, 0.33333333, 0.52542373, 0.5       ],
#        [0.55555556, 0.54166667, 0.84745763, 1.        ],
#        [0.41666667, 0.29166667, 0.69491525, 0.75      ],
#        [0.77777778, 0.41666667, 0.83050847, 0.83333333],
#        [0.55555556, 0.375     , 0.77966102, 0.70833333],
#        [0.61111111, 0.41666667, 0.81355932, 0.875     ],
#        [0.91666667, 0.41666667, 0.94915254, 0.83333333],
#        [0.16666667, 0.20833333, 0.59322034, 0.66666667],
#        [0.83333333, 0.375     , 0.89830508, 0.70833333],
#        [0.66666667, 0.20833333, 0.81355932, 0.70833333],
#        [0.80555556, 0.66666667, 0.86440678, 1.        ],
#        [0.61111111, 0.5       , 0.69491525, 0.79166667],
#        [0.58333333, 0.29166667, 0.72881356, 0.75      ],
#        [0.69444444, 0.41666667, 0.76271186, 0.83333333],
#        [0.38888889, 0.20833333, 0.6779661 , 0.79166667],
#        [0.41666667, 0.33333333, 0.69491525, 0.95833333],
#        [0.58333333, 0.5       , 0.72881356, 0.91666667],
#        [0.61111111, 0.41666667, 0.76271186, 0.70833333],
#        [0.94444444, 0.75      , 0.96610169, 0.875     ],
#        [0.94444444, 0.25      , 1.        , 0.91666667],
#        [0.47222222, 0.08333333, 0.6779661 , 0.58333333],
#        [0.72222222, 0.5       , 0.79661017, 0.91666667],
#        [0.36111111, 0.33333333, 0.66101695, 0.79166667],
#        [0.94444444, 0.33333333, 0.96610169, 0.79166667],
#        [0.55555556, 0.29166667, 0.66101695, 0.70833333],
#        [0.66666667, 0.54166667, 0.79661017, 0.83333333],
#        [0.80555556, 0.5       , 0.84745763, 0.70833333],
#        [0.52777778, 0.33333333, 0.6440678 , 0.70833333],
#        [0.5       , 0.41666667, 0.66101695, 0.70833333],
#        [0.58333333, 0.33333333, 0.77966102, 0.83333333],
#        [0.80555556, 0.41666667, 0.81355932, 0.625     ],
#        [0.86111111, 0.33333333, 0.86440678, 0.75      ],
#        [1.        , 0.75      , 0.91525424, 0.79166667],
#        [0.58333333, 0.33333333, 0.77966102, 0.875     ],
#        [0.55555556, 0.33333333, 0.69491525, 0.58333333],
#        [0.5       , 0.25      , 0.77966102, 0.54166667],
#        [0.94444444, 0.41666667, 0.86440678, 0.91666667],
#        [0.55555556, 0.58333333, 0.77966102, 0.95833333],
#        [0.58333333, 0.45833333, 0.76271186, 0.70833333],
#        [0.47222222, 0.41666667, 0.6440678 , 0.70833333],
#        [0.72222222, 0.45833333, 0.74576271, 0.83333333],
#        [0.66666667, 0.45833333, 0.77966102, 0.95833333],
#        [0.72222222, 0.45833333, 0.69491525, 0.91666667],
#        [0.41666667, 0.29166667, 0.69491525, 0.75      ],
#        [0.69444444, 0.5       , 0.83050847, 0.91666667],
#        [0.66666667, 0.54166667, 0.79661017, 1.        ],
#        [0.66666667, 0.41666667, 0.71186441, 0.91666667],
#        [0.55555556, 0.20833333, 0.6779661 , 0.75      ],
#        [0.61111111, 0.41666667, 0.71186441, 0.79166667],
#        [0.52777778, 0.58333333, 0.74576271, 0.91666667],
#        [0.44444444, 0.41666667, 0.69491525, 0.70833333]])

# %% [markdown]
# Lakukan pembagian data menjadi data latih dan data uji. Untuk ukuran data testing yang digunakan 30%. Anda dapat bereksperimen menggunakan nilai lainnya.

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, y, test_size=0.3)

# %% [markdown]
# Untuk arsitektur model kita kali ini menggunakan 3 buah layer. Activation function yang digunakan pada layer terakhir dipilih 'softmax' karena activation tersebut umum dipakai untuk klasifikasi multi kelas seperti ini

# %%
model = Sequential([
                    Dense(64, activation='relu', input_shape=(4,)),
                    Dense(64, activation='relu'),
                    Dense(3, activation='softmax')
])

# %% [markdown]
# Lanjutkan dengan menentukan *optimizer* dan *loss* function dari model. Untuk masalah klasifikasi multi kelas, Anda dapat menggunakan loss ‘categorical_crossentropy’.

# %%
model.compile(optimizer='Adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Nah, pada latihan ini ada sedikit perubahan. Fungsi `fit()` sekarang kita tampung ke dalam objek hist (history). Untuk apa kita melakukan hal ini? Temukan jawabannya di submodul berikutnya ya.

# %%
# Hasilnya sebagai berikut:
hist = model.fit(X_train, Y_train, epochs=100)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 4ms/step - loss: 1.0786 - accuracy: 0.3429
# Epoch 2/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0469 - accuracy: 0.3429
# Epoch 3/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0206 - accuracy: 0.5810
# Epoch 4/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9935 - accuracy: 0.6667
# Epoch 5/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9679 - accuracy: 0.6762
# Epoch 6/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9427 - accuracy: 0.6857
# Epoch 7/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9155 - accuracy: 0.6857
# Epoch 8/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8867 - accuracy: 0.6857
# Epoch 9/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8574 - accuracy: 0.6857
# Epoch 10/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8277 - accuracy: 0.6857
# Epoch 11/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7974 - accuracy: 0.6857
# Epoch 12/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7653 - accuracy: 0.6857
# Epoch 13/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7334 - accuracy: 0.6857
# Epoch 14/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7004 - accuracy: 0.6857
# Epoch 15/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6698 - accuracy: 0.6857
# Epoch 16/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6405 - accuracy: 0.6857
# Epoch 17/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6125 - accuracy: 0.6857
# Epoch 18/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5861 - accuracy: 0.6857
# Epoch 19/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5598 - accuracy: 0.6857
# Epoch 20/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5371 - accuracy: 0.6857
# Epoch 21/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5160 - accuracy: 0.6952
# Epoch 22/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4968 - accuracy: 0.7143
# Epoch 23/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4789 - accuracy: 0.7238
# Epoch 24/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4631 - accuracy: 0.7238
# Epoch 25/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4481 - accuracy: 0.7333
# Epoch 26/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4358 - accuracy: 0.7333
# Epoch 27/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4238 - accuracy: 0.7333
# Epoch 28/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4109 - accuracy: 0.7810
# Epoch 29/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4004 - accuracy: 0.8857
# Epoch 30/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3907 - accuracy: 0.9333
# Epoch 31/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3828 - accuracy: 0.9333
# Epoch 32/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3710 - accuracy: 0.9333
# Epoch 33/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3608 - accuracy: 0.9333
# Epoch 34/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3519 - accuracy: 0.9333
# Epoch 35/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3425 - accuracy: 0.9333
# Epoch 36/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3325 - accuracy: 0.9333
# Epoch 37/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3224 - accuracy: 0.9333
# Epoch 38/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3132 - accuracy: 0.9333
# Epoch 39/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3051 - accuracy: 0.9333
# Epoch 40/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2945 - accuracy: 0.9333
# Epoch 41/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2928 - accuracy: 0.9333
# Epoch 42/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2804 - accuracy: 0.9619
# Epoch 43/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2693 - accuracy: 0.9619
# Epoch 44/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2617 - accuracy: 0.9524
# Epoch 45/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2552 - accuracy: 0.9333
# Epoch 46/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2476 - accuracy: 0.9524
# Epoch 47/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2399 - accuracy: 0.9619
# Epoch 48/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2331 - accuracy: 0.9619
# Epoch 49/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2254 - accuracy: 0.9619
# Epoch 50/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2241 - accuracy: 0.9429
# Epoch 51/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2176 - accuracy: 0.9429
# Epoch 52/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2107 - accuracy: 0.9429
# Epoch 53/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2029 - accuracy: 0.9619
# Epoch 54/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1969 - accuracy: 0.9619
# Epoch 55/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1915 - accuracy: 0.9619
# Epoch 56/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1879 - accuracy: 0.9619
# Epoch 57/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1816 - accuracy: 0.9619
# Epoch 58/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1782 - accuracy: 0.9429
# Epoch 59/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1787 - accuracy: 0.9429
# Epoch 60/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1693 - accuracy: 0.9619
# Epoch 61/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1653 - accuracy: 0.9619
# Epoch 62/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1655 - accuracy: 0.9619
# Epoch 63/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1574 - accuracy: 0.9619
# Epoch 64/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1544 - accuracy: 0.9714
# Epoch 65/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1518 - accuracy: 0.9714
# Epoch 66/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1470 - accuracy: 0.9714
# Epoch 67/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1440 - accuracy: 0.9619
# Epoch 68/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1450 - accuracy: 0.9619
# Epoch 69/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1426 - accuracy: 0.9619
# Epoch 70/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1372 - accuracy: 0.9619
# Epoch 71/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1338 - accuracy: 0.9714
# Epoch 72/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1300 - accuracy: 0.9619
# Epoch 73/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1357 - accuracy: 0.9619
# Epoch 74/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1404 - accuracy: 0.9524
# Epoch 75/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1249 - accuracy: 0.9524
# Epoch 76/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1230 - accuracy: 0.9714
# Epoch 77/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1308 - accuracy: 0.9524
# Epoch 78/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1235 - accuracy: 0.9619
# Epoch 79/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1181 - accuracy: 0.9619
# Epoch 80/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1160 - accuracy: 0.9619
# Epoch 81/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1136 - accuracy: 0.9619
# Epoch 82/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1118 - accuracy: 0.9619
# Epoch 83/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1125 - accuracy: 0.9524
# Epoch 84/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1096 - accuracy: 0.9524
# Epoch 85/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1105 - accuracy: 0.9619
# Epoch 86/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1116 - accuracy: 0.9619
# Epoch 87/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1087 - accuracy: 0.9619
# Epoch 88/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1036 - accuracy: 0.9714
# Epoch 89/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1027 - accuracy: 0.9619
# Epoch 90/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1025 - accuracy: 0.9619
# Epoch 91/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1007 - accuracy: 0.9619
# Epoch 92/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1003 - accuracy: 0.9619
# Epoch 93/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0982 - accuracy: 0.9714
# Epoch 94/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1009 - accuracy: 0.9619
# Epoch 95/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0973 - accuracy: 0.9619
# Epoch 96/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0978 - accuracy: 0.9619
# Epoch 97/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0996 - accuracy: 0.9619
# Epoch 98/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0946 - accuracy: 0.9619
# Epoch 99/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0938 - accuracy: 0.9619
# Epoch 100/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0920 - accuracy: 0.9619

# %% [markdown]
# Terakhir kita bisa menguji akurasi prediksi model pada data uji.

# %%
model.evaluate(X_test, Y_test)
# Out:
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0747 - accuracy: 0.9778
# [0.07467325031757355, 0.9777777791023254]
